# %%
import pandas as pd
import matplotlib.pyplot as plt

# Les CSV-fil
filnavn = r"C:\Users\olavh\Documents\EIT\data\Rema1000 før VM, LAeq - Sheet1.csv"
df = pd.read_csv(filnavn)

# Juster sampling rate (f.eks. 1 = alle punkter, 2 = hvert andre punkt, 10 = hvert tiende punkt)
sampling_rate = 40

# Forventet at CSV-filen har kolonner: "tid", "channel_1", "channel_2"
tid = df.iloc[::sampling_rate, 0] / 60  # Konverter sekunder til minutter
channel_1 = df.iloc[::sampling_rate, 1]
channel_2 = df.iloc[::sampling_rate, 2]

# Plotting
plt.figure(figsize=(10, 5))
plt.plot(tid, channel_1, label="Channel 1", linestyle="-", marker="o")
plt.plot(tid, channel_2, label="Channel 2", linestyle="-", marker="s")

# Tilpass plot
plt.xlabel("Tid (minutter)")
plt.ylabel("Lydnivå LAeq (dB)")
plt.title("Mot Flatåsen, før VM")
plt.legend()
plt.grid()

# Lagre plottet som en SVG-fil før det vises
svg_filnavn = filnavn.rsplit(".", 1)[0] + "_rapport.svg"  # Samme mappe, nytt navn
plt.savefig(svg_filnavn, format="svg")

# Vis plottet
plt.show()

# %%
# Les CSV-fil
filnavn = r"C:\Users\olavh\Documents\EIT\data\Rema1000 VM økt1, LAeq - Sheet1.csv"
df = pd.read_csv(filnavn)

# Juster sampling rate (f.eks. 1 = alle punkter, 2 = hvert andre punkt, 10 = hvert tiende punkt)
sampling_rate = 40

# Forventet at CSV-filen har kolonner: "tid", "channel_1", "channel_2"
tid = df.iloc[::sampling_rate, 0] / 60  # Konverter sekunder til minutter
channel_1 = df.iloc[::sampling_rate, 1]
channel_2 = df.iloc[::sampling_rate, 2]

# Plotting
plt.figure(figsize=(10, 5))
plt.plot(tid, channel_1, label="Channel 1", linestyle="-", marker="o")
plt.plot(tid, channel_2, label="Channel 2", linestyle="-", marker="s")

# Tilpass plot
plt.xlabel("Tid (minutter)")
plt.ylabel("Lydnivå LAeq (dB)")
plt.title("Mot Flatåsen, under VM")
plt.legend()
plt.grid()

# Lagre plottet som en SVG-fil før det vises
svg_filnavn = filnavn.rsplit(".", 1)[0] + "_rapport.svg"  # Samme mappe, nytt navn
plt.savefig(svg_filnavn, format="svg")

# Vis plottet
plt.show()

# %%
# Les CSV-fil
filnavn = r"C:\Users\olavh\Documents\EIT\data\Rema1000 VM stafett, LAeq - Sheet1.csv"
df = pd.read_csv(filnavn)

# Juster sampling rate (f.eks. 1 = alle punkter, 2 = hvert andre punkt, 10 = hvert tiende punkt)
sampling_rate = 40

# Forventet at CSV-filen har kolonner: "tid", "channel_1", "channel_2"
tid = df.iloc[::sampling_rate, 0] / 60  # Konverter sekunder til minutter
channel_1 = df.iloc[::sampling_rate, 1]
channel_2 = df.iloc[::sampling_rate, 2]

# Plotting
plt.figure(figsize=(10, 5))
plt.plot(tid, channel_1, label="Channel 1", linestyle="-", marker="o")
plt.plot(tid, channel_2, label="Channel 2", linestyle="-", marker="s")

# Tilpass plot
plt.xlabel("Tid (minutter)")
plt.ylabel("Lydnivå LAeq (dB)")
plt.title("Mot Flatåsen, under en VM stafett")
plt.legend()
plt.grid()

# Lagre plottet som en SVG-fil før det vises
svg_filnavn = filnavn.rsplit(".", 1)[0] + "_rapport.svg"  # Samme mappe, nytt navn
plt.savefig(svg_filnavn, format="svg")

# Vis plottet
plt.show()

# %%
# Les CSV-fil
filnavn = r"C:\Users\olavh\Documents\EIT\data\Myren før VM, LAeq - Sheet1.csv"
df = pd.read_csv(filnavn)

# Juster sampling rate (f.eks. 1 = alle punkter, 2 = hvert andre punkt, 10 = hvert tiende punkt)
sampling_rate = 40

# Forventet at CSV-filen har kolonner: "tid", "channel_1", "channel_2"
tid = df.iloc[::sampling_rate, 0] / 60  # Konverter sekunder til minutter
channel_1 = df.iloc[::sampling_rate, 1]
channel_2 = df.iloc[::sampling_rate, 2]

# Plotting
plt.figure(figsize=(10, 5))
plt.plot(tid, channel_1, label="Channel 1", linestyle="-", marker="o")
plt.plot(tid, channel_2, label="Channel 2", linestyle="-", marker="s")

# Tilpass plot
plt.xlabel("Tid (minutter)")
plt.ylabel("Lydnivå LAeq (dB)")
plt.title("Mot Byåsen, før VM")
plt.legend()
plt.grid()

# Lagre plottet som en SVG-fil før det vises
svg_filnavn = filnavn.rsplit(".", 1)[0] + "_rapport.svg"  # Samme mappe, nytt navn
plt.savefig(svg_filnavn, format="svg")

# Vis plottet
plt.show()

# %%
# Les CSV-fil
filnavn = r"C:\Users\olavh\Documents\EIT\data\Myren under VM, LAeq - Sheet1.csv"
df = pd.read_csv(filnavn)

# Juster sampling rate (f.eks. 1 = alle punkter, 2 = hvert andre punkt, 10 = hvert tiende punkt)
sampling_rate = 40

# Forventet at CSV-filen har kolonner: "tid", "channel_1", "channel_2"
tid = df.iloc[::sampling_rate, 0] / 60  # Konverter sekunder til minutter
channel_1 = df.iloc[::sampling_rate, 1]
channel_2 = df.iloc[::sampling_rate, 2]

# Plotting
plt.figure(figsize=(10, 5))
plt.plot(tid, channel_1, label="Channel 1", linestyle="-", marker="o")
plt.plot(tid, channel_2, label="Channel 2", linestyle="-", marker="s")

# Tilpass plot
plt.xlabel("Tid (minutter)")
plt.ylabel("Lydnivå LAeq (dB)")
plt.title("Mot Byåsen, under VM")
plt.legend()
plt.grid()

# Lagre plottet som en SVG-fil før det vises
svg_filnavn = filnavn.rsplit(".", 1)[0] + "_rapport.svg"  # Samme mappe, nytt navn
plt.savefig(svg_filnavn, format="svg")

# Vis plottet
plt.show()

# %%
# Les CSV-fil
filnavn = r"C:\Users\olavh\Documents\EIT\data\Veien mot Flatåsen, før VM, LAeq - Sheet1.csv"
df = pd.read_csv(filnavn)

# Juster sampling rate (f.eks. 1 = alle punkter, 2 = hvert andre punkt, 10 = hvert tiende punkt)
sampling_rate = 40

# Forventet at CSV-filen har kolonner: "tid", "channel_1", "channel_2"
tid = df.iloc[::sampling_rate, 0] / 60  # Konverter sekunder til minutter
channel_1 = df.iloc[::sampling_rate, 1]
channel_2 = df.iloc[::sampling_rate, 2]

# Plotting
plt.figure(figsize=(10, 5))
plt.plot(tid, channel_1, label="Channel 1", linestyle="-", marker="o")
plt.plot(tid, channel_2, label="Channel 2", linestyle="-", marker="s")

# Tilpass plot
plt.xlabel("Tid (minutter)")
plt.ylabel("Lydnivå LAeq (dB)")
plt.title("Vei mot Flatåsen, før VM")
plt.legend()
plt.grid()

# Lagre plottet som en SVG-fil før det vises
svg_filnavn = filnavn.rsplit(".", 1)[0] + "_rapport.svg"  # Samme mappe, nytt navn
plt.savefig(svg_filnavn, format="svg")

# Vis plottet
plt.show()

# %%
# Les CSV-fil
filnavn = r"C:\Users\olavh\Documents\EIT\data\Veien mot Flatåsen, under VM, LAeq - Sheet1.csv"
df = pd.read_csv(filnavn)

# Juster sampling rate (f.eks. 1 = alle punkter, 2 = hvert andre punkt, 10 = hvert tiende punkt)
sampling_rate = 40

# Forventet at CSV-filen har kolonner: "tid", "channel_1", "channel_2"
tid = df.iloc[::sampling_rate, 0] / 60  # Konverter sekunder til minutter
channel_1 = df.iloc[::sampling_rate, 1]
channel_2 = df.iloc[::sampling_rate, 2]

# Plotting
plt.figure(figsize=(10, 5))
plt.plot(tid, channel_1, label="Channel 1", linestyle="-", marker="o")
plt.plot(tid, channel_2, label="Channel 2", linestyle="-", marker="s")

# Tilpass plot
plt.xlabel("Tid (minutter)")
plt.ylabel("Lydnivå LAeq (dB)")
plt.title("Vei mot Flatåsen, under VM")
plt.legend()
plt.grid()

# Lagre plottet som en SVG-fil før det vises
svg_filnavn = filnavn.rsplit(".", 1)[0] + "_rapport.svg"  # Samme mappe, nytt navn
plt.savefig(svg_filnavn, format="svg")

# Vis plottet
plt.show()

# %%
# Gå på 05_Results.tex i sections i prosjektrapporten. Linje 14-20 er den for å få inn bildene.

#\begin{figure}[H] 
#    \centering
#    \includesvg[width=1\textwidth]
#    {images/måledata/Rema1000 før VM, LAeq - Sheet1_rapport}
#    \caption{Eksempel plotting av data}
#    \label{rema}
#\end{figure}
